# %% [markdown]
# **Movie prediction using Machine Learning![Screenshot 2024-02-18 220139.png](data:image/png;base64,...)**

# %%
I made this code by watching a video about KNN Classification in Machine Learning.

# %% [markdown]
# [Video Link](https://www.youtube.com/watch?v=O1nWXTXcCwI&t=327s&ab_channel=GateSmashers)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie=pd.read_csv('/content/Movie_Dataset.csv')

# %%
movie.head(5)
# Out:
#    IMDB  Duration   Genre
# 0   8.0       160  Action
# 1   6.2       170  Action
# 2   7.2       168  Comedy
# 3   8.2       155  Comedy

# %%
from sklearn.model_selection import train_test_split

# %%
X=movie[['IMDB', 'Duration']]

# %%
y=movie['Genre']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Knn=KNeighborsClassifier(n_neighbors=1)

# %%
Knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
Knn.score(X_test,y_test)
# Out:
# 0.0

# %%
knn = KNeighborsClassifier(n_neighbors=1, metric='minkowski', p=2)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
movie_prediction = knn.predict([[7.4, 144]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Predicted Movie Genre:", movie_prediction[0])
# Out:
# Predicted Movie Genre: Comedy
